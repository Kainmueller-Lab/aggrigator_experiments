# %%
import numpy as np
import matplotlib.pyplot as plt
from spatial_decomposition import spatial_decomposition, UncertaintyMap

# %%
array = np.load('/fast/AG_Kainmueller/data/ValUES/UQ_spatial/fgbg_noise_0_texture_0_00_dropout_pu_high_eds.npy', allow_pickle=True)

# %%
plt.imshow(array[0])
